# %% [markdown]
# <a href="https://colab.research.google.com/github/aravind2060/customer_churn_spark/blob/master/Customer_churn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
from pyspark.sql import SparkSession
from pyspark.ml.feature import StringIndexer, OneHotEncoder, VectorAssembler, ChiSqSelector
from pyspark.ml.classification import LogisticRegression
from pyspark.ml.evaluation import BinaryClassificationEvaluator

# %%
# Update packages and install Java 17
# !apt-get update
# !apt-get install -y openjdk-17-jdk


# Set JAVA_HOME to Java 17 installation path
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-17-openjdk-amd64"
os.environ["PATH"] = os.environ["JAVA_HOME"] + "/bin:" + os.environ["PATH"]

# check java version
# !java -version

# %%
# Start Spark session
spark = SparkSession.builder.appName("CustomerChurnMLlib").getOrCreate()

# %%
# Load dataset
data_path = "customer_churn.csv"
df = spark.read.csv(data_path, header=True, inferSchema=True)

# %%
df.show(10);
# Out:
# +----------+------+-------------+------+------------+---------------+--------------+------------+-----+
# |customerID|gender|SeniorCitizen|tenure|PhoneService|InternetService|MonthlyCharges|TotalCharges|Churn|
# +----------+------+-------------+------+------------+---------------+--------------+------------+-----+
# | CUST00001|  Male|            0|    71|         Yes|    Fiber optic|          93.5|     6867.33|   No|
# | CUST00002|Female|            1|     2|          No|            DSL|         96.44|      203.38|   No|
# | CUST00003|  Male|            0|     7|          No|             No|          98.6|      655.38|   No|
# | CUST00004|Female|            0|     5|          No|            DSL|        103.22|      490.97|  Yes|
# | CUST00005|  Male|            0|     5|         Yes|    Fiber optic|         63.17|      336.16|   No|
# | CUST00006|Female|            0|    59|          No|    Fiber optic|         89.65|     5710.89|  Yes|
# ...

# %%
# ---------------------------------------------------
# Task 1: Data Preprocessing
# ---------------------------------------------------
def preprocess_data(df):
    """
    1. Handle missing values in numeric columns appropriately.
    2. Convert categorical columns into a numeric format suitable for machine learning.
    3. Combine all relevant numeric and transformed categorical features into a single feature column.
    4. Convert the target column (Churn) into a numeric label column.

    Returns:
        DataFrame with 'features' column and 'label' column.
    """
    pass

# %%
# ---------------------------------------------------
# Task 2: Feature Selection
# ---------------------------------------------------
def feature_selection(df):
    """
    1. Identify the most important features for predicting churn using appropriate methods.
    2. Reduce the feature set to the top features that contribute most to predictions.
    3. Create at least one new derived feature based on existing columns (e.g., bucket tenure or compute ratios).

    Returns:
        DataFrame with updated 'features' column and 'label' column.
    """
    pass

# %%
# ---------------------------------------------------
# Task 3: Train and Compare Models
# ---------------------------------------------------
def train_and_compare_models(df):
    """
    1. Split the dataset into training and test sets.
    2. Train at least two machine learning models on the training set (e.g., one linear model and one tree-based model).
    3. Generate predictions on the test set for both models.
    4. Evaluate both models using appropriate metrics for classification (e.g., AUC).
    5. Print the performance of each model and identify the best one.
    6. Save the best model to disk and demonstrate loading it back for predictions.
    """
    pass

# %%
# pipeline
processed_df = preprocess_data(df)
selected_df = feature_selection(processed_df)
train_and_compare_models(selected_df)

# Stop Spark session
spark.stop()
